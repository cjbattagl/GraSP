# %% [markdown]
# # Purpose

# %% [markdown]
# The purpose of this notebook is to analyze a few selected SNAP graphs found at https://sparse.tamu.edu/SNAP for "interesting" characteristics.

# %% [markdown]
# ## web-Stanford

# %% [markdown]
# This graph maps stanford.edu, with nodes representing web pages and the edges representing the hyperlinks between them. This graph is directed and can be found at https://sparse.tamu.edu/SNAP/web-Stanford.

# %%
from scipy.io import mmread, mminfo
G1 = mmread("web-Stanford.mtx")
mminfo("web-Stanford.mtx")
# Out:
# (281903, 281903, 2312497, 'coordinate', 'pattern', 'general')

# %% [markdown]
# Number of vertices: 281903
#
# Number of edges: 2312497
#
# G1 = (281903, 2312497)

# %%
type(G1)
# Out:
# scipy.sparse.coo.coo_matrix

# %%
# ?G1.*

# %%
G1.shape
# Out:
# (281903, 281903)

# %%
from matplotlib.pyplot import spy
# %matplotlib inline
spy(G1,markersize=0.005)

# %%
v = G1.getrow(1)
print(v)
# Out:
#   (0, 280934)	1.0
#   (0, 252914)	1.0
#   (0, 251657)	1.0
#   (0, 246896)	1.0
#   (0, 243293)	1.0
#   (0, 241595)	1.0
#   (0, 225118)	1.0
#   (0, 213965)	1.0
#   (0, 210869)	1.0
#   (0, 204603)	1.0
#   (0, 204188)	1.0
#   (0, 190452)	1.0
#   (0, 181713)	1.0
#   (0, 178641)	1.0
#   (0, 175798)	1.0
#   (0, 164598)	1.0
#   (0, 163549)	1.0
#   (0, 140863)	1.0
#   (0, 115925)	1.0
#   (0, 105729)	1.0
#   (0, 105317)	1.0
#   (0, 102354)	1.0
#   (0, 100192)	1.0
#   (0, 98627)	1.0
#   (0, 84476)	1.0
#   (0, 73763)	1.0
#   (0, 64929)	1.0
#   (0, 54581)	1.0
#   (0, 53624)	1.0
#   (0, 25201)	1.0
#   (0, 17793)	1.0

# %%
v.count_nonzero()
v.sum()
# Out:
# 31.0

# %%
v.getnnz(axis = 0)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
count = 0
node1_neighbors = []
nodes = 281903
while count < nodes:
    if v.getcol(count) == 1:
        node1_neighbors.append(count)
    count = count + 1
print(node1_neighbors)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-40333daeaa5f> in <module>()
#       3 nodes = 281903
#       4 while count < nodes:
# ----> 5     if v.getcol(count) == 1:
#       6         node1_neighbors.append(count)
#       7     count = count + 1
#
# /Users/cjbatta/anaconda/lib/python3.5/site-packages/scipy/sparse/compressed.py in __eq__(self, other)
#     216                 return all_true - inv
#     217             else:
# --> 218                 return self._scalar_binopt(other, operator.eq)
#     219         # Dense other.
#     220         elif isdense(other):
#
# /Users/cjbatta/anaconda/lib/python3.5/site-packages/scipy/sparse/compressed.py in _scalar_binopt(self, other, op)
#     200         self.sum_duplicates()
#     201         res = self._with_data(op(self.data, other), copy=True)
# --> 202         res.eliminate_zeros()
#     203         return res
#     204
#
# /Users/cjbatta/anaconda/lib/python3.5/site-packages/scipy/sparse/compressed.py in eliminate_zeros(self)
#     924     ##############################################################
#     925
# --> 926     def eliminate_zeros(self):
#     927         """Remove zero entries from the matrix
#     928
#
# KeyboardInterrupt:

# %% [markdown]
# N(1) = {17793, 25201, 53624, 54581, 64929, 73763, 84476, 100192, 102354, 105317, 105729, 115925, 140863, 163549, 164598, 175798, 178641, 181713, 190452, 204188, 204603, 210869, 213965, 225118, 241595, 243293, 246896, 251657, 252914, 280934}

# %%
G1.

# %%
nodes = 281903

degrees = G1.sum(axis=1)

total_degree = sum(int(i) for i in degrees)
    
average = total_degree/nodes
print(average)
# Out:
# 8.203165627893283

# %% [markdown]
# ## roadNet-PA

# %% [markdown]
# This is an undirected graph of the raod network in Pennsylvania as of 2008, with nodes representing intersections and endpoints and edges representing the road between them. The graph can be found at https://sparse.tamu.edu/SNAP/roadNet-PA.

# %%
#from scipy.io import mmread, mminfo
G2 = mmread("roadNet-PA.mtx")
mminfo("roadNet-Pa.mtx")
# Out:
# (1090920, 1090920, 1541898, 'coordinate', 'pattern', 'symmetric')

# %% [markdown]
# Number of vertices: 1090920
#
# Number of edges: 1541898
#
# G2 = (1090920, 1541898)

# %%
# %matplotlib inline
spy(G2,markersize=0.5)

# %%
foo = G2.sum(axis=1)
print(foo[0])
v = G2.getrow(0)
print(v)
# Out:
# [[ 3.]]
#   (0, 6353)	1.0
#   (0, 6309)	1.0
#   (0, 1)	1.0
